# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
plt.hist(df['sepal_length'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['sepal_width'])
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['petal_length'])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['petal_width'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['species'])
# Out:
# (array([50.,  0.,  0.,  0.,  0., 50.,  0.,  0.,  0., 50.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['sepal_length'])
plt.title("Box plot for sepal_length")
plt.show()

# %%
plt.boxplot(df['sepal_width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1534f155010>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1534f157b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1534f155990>],
#  'medians': [<matplotlib.lines.Line2D at 0x1534f15d090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1534f15d910>],
#  'means': []}

# %%
plt.boxplot(df['petal_length'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1534f1bddd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1534f1bf610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1534f1bd2d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1534f1d0bd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1534f1d1710>],
#  'means': []}

# %%
plt.boxplot(df['petal_width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1534f366990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1534f370190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1534f365e90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1534f371690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1534f372090>],
#  'means': []}

# %%
sns.pairplot(df)
# Out:
# C:\Users\Bhargavi\Documents\ANAcondafiles\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Bhargavi\Documents\ANAcondafiles\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Bhargavi\Documents\ANAcondafiles\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Histograms:
# Plot histograms for each numerical column (sepal_length, sepal_width, petal_length, petal_width) using plt.hist().
# Each histogram displays the distribution of values for the respective feature.
# Box Plots:
# Plot box plots for each numerical column (sepal_length, sepal_width, petal_length, petal_width) using plt.boxplot().
# Box plots provide a visual summary of the central tendency, dispersion, and distribution of the data.
# Pair Plot:
# Generate a pair plot of the dataset using sns.pairplot().
# Pair plots provide a visual overview of the relationships between pairs of variables in the dataset.
